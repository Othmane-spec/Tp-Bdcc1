# %%
import tiktoken

# %%
encoding = tiktoken.encoding_for_model("gpt-4o")
print(encoding.name)
# Out:
# o200k_base

# %%
system_message ="""
Perform Sentiment analysis of the review presented in the user message.
The result should be positive or negative. Do not justify your response
"""
tokens = encoding.encode(system_message)

# %%
print(tokens)
# Out:
# [198, 73751, 31712, 2581, 8450, 328, 290, 3358, 13392, 306, 290, 1825, 3176, 558, 976, 1534, 1757, 413, 8841, 503, 12626, 13, 3756, 625, 14883, 634, 3322, 198]

# %%
for token in tokens:
    print(encoding.decode_single_token_bytes(token), end="")
# Out:
# b'\n'b'Perform'b' Sent'b'iment'b' analysis'b' of'b' the'b' review'b' presented'b' in'b' the'b' user'b' message'b'.\n'b'The'b' result'b' should'b' be'b' positive'b' or'b' negative'b'.'b' Do'b' not'b' justify'b' your'b' response'b'\n'

# %%
print(len(tokens))
# Out:
# 28

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2")

response = llm.invoke([
    {"role": "system", "content": "You are a helpful assistant. The output should be in Markdown"},
    {"role": "user", "content": "C'est quoi un Agent AI"}
])

# %%
from IPython.display import Markdown, display
print(display(Markdown(response.content)))
# Out:
# # Qu'est-ce qu'un Agent AI ?
#
# Un **Agent AI** (Automaton Intelligence) est un système informatique conçu pour simuler des comportements intelligents, tels que la pensée et l'apprentissage. Il s'agit d'un élément clé dans les systèmes intelligentes, qui peut interagir avec son environnement de manière autonome.
#
# ## Fonctionnalités d'un Agent AI
#
# Un agent AI possède les fonctions suivantes :
#
# * **Présence** : L'agent est présent dans un environnement virtuel ou réel.
# * **Perception** : L'agent perçoit ses données à partir de son environnement, telles que des capteurs, des cameras, etc.
# * **Compréhension** : L'agent comprend les informations qu'il perçoit et les traite pour obtenir une compréhension du monde qui l'entoure.
# * **Action** : L'agent prend des décisions pour agir sur son environnement, telles que de bouger, d'écrire un message, etc.
# * **Apprentissage** : L'agent apprend et mémorise des connaissances à partir de ses expériences.
#
# ## Types d'Agents AI
#
# Il existe plusieurs types d'agents AI :
#
# * **Agent de détection (Detector)** : Identifie des objets ou des événements dans son environnement.
# * **Agent de navigation (Navigator)** : Explore et se déplace à travers son environnement pour atteindre un objectif spécifique.
# * **Agent de décision (Decider)** : Prend des décisions basées sur des règles ou des modèles d'apprentissage.
# * **Agent de planification (Planner)** : Crée des plans pour atteindre un objectif spécifique.
#
# ## Exemples d'Agents AI
#
# * Un robot qui explore et navigue dans son environnement pour éviter les obstacles et atteindre une cible.
# * Un système de recommandation de films sur un site web, qui utilise des algorithmes d'apprentissage automatique pour suggérer des films en fonction des préférences du'utilisateur.
# * Un système d'intelligence artificielle virtuelle qui répond aux questions et réagit à des demandes provenant d'un utilisateur.
#
# En résumé, un agent AI est un système informatique qui peut simuler des comportements intelligents et interagir avec son environnement de manière autonome. Il possède les fonctions de présence, perception, compréhension, action et apprentissage, et existe sous différentes formes pour s'adapter à différents contextes.
# None

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm2 = ChatGroq(model="openai/gpt-oss-120b")

from langchain.messages import SystemMessage, HumanMessage
resp2 = llm2.invoke([

SystemMessage("You are a helpful assistant. The output should be in Mark-down"),

HumanMessage("C'est quoi un Agent AI")
])
print(display(Markdown(resp2.content)))
# Out:
# ## Qu’est‑ce qu’un **Agent IA** ?
#
# Un **agent d’intelligence artificielle (IA)** est un logiciel ou un système capable d’interagir avec son environnement, de percevoir des informations, de prendre des décisions et d’agir de façon autonome ou semi‑autonome pour atteindre un ou plusieurs objectifs.
#
# ### 1. Principes de base
#
# | Élément | Description |
# |--------|-------------|
# | **Perception** | L’agent reçoit des données (capteurs, API, texte, images, etc.) qui décrivent l’état du monde extérieur ou d’un environnement virtuel. |
# | **Modélisation** | Il transforme ces données brutes en une représentation interne (ex. : état du jeu, intentions de l’utilisateur, contexte de la conversation). |
# | **Décision / Planification** | À partir de cette représentation, l’agent choisit une action en se basant sur des règles, des modèles statistiques, du raisonnement logique ou de l’apprentissage (reinforcement learning, réseaux de neurones, etc.). |
# | **Action** | L’agent exécute l’action sélectionnée (envoi d’un message, déplacement d’un robot, modification d’une base de données, etc.). |
# | **Boucle de rétroaction** | Le résultat de l’action est à nouveau perçu, ce qui permet à l’agent d’ajuster son comportement en temps réel. |
#
# ### 2. Types d’agents IA
#
# | Catégorie | Exemple | Particularités |
# |-----------|---------|----------------|
# | **Agent réactif** | Agent de jeu vidéo qui répond instantanément aux mouvements du joueur. | Pas de mémoire à long terme ; décisions basées uniquement sur l’état actuel. |
# | **Agent basé sur un modèle** | Chatbot qui garde le contexte d’une conversation sur plusieurs tours. | Maintient une représentation interne (mémoire) du passé. |
# | **Agent orienté but** | Système de navigation autonome qui cherche le chemin le plus court vers une destination. | Possède un objectif explicite et planifie des actions pour l’atteindre. |
# | **Agent d’apprentissage** | Robot qui apprend à saisir des objets grâce au **reinforcement learning**. | Améliore ses politiques d’action grâce à l’expérience. |
# | **Agent hybride** | Assistant vocal (ex. : Alexa, Google Assistant) qui combine reconnaissance vocale, compréhension du langage, recherche d’informations et contrôle de dispositifs domotiques. | Combine plusieurs techniques (règles, apprentissage, planification). |
#
# ### 3. Architecture typique d’un agent IA
#
# ```mermaid
# graph LR
#     A[Capteurs / Entrées] --> B[Pré‑traitement]
#     B --> C[Modèle de perception (NLP, CV, etc.)]
#     C --> D[Représentation de l’état]
#     D --> E[Planificateur / Politique d’action]
#     E --> F[Actionneur / Sortie]
#     F --> G[Environnement]
#     G --> A   %% boucle de rétroaction
# ```
#
# 1. **Capteurs / Entrées** : données brutes (texte, audio, images, mesures physiques).
# 2. **Pré‑traitement** : nettoyage, normalisation, extraction de caractéristiques.
# 3. **Modèle de perception** : réseaux de neurones, pipelines NLP, détecteurs d’objets, etc.
# 4. **Représentation de l’état** : vecteurs, graphes, bases de connaissances.
# 5. **Planificateur / Politique** : algorithmes de décision (rules‑engine, MDP, deep RL, arbres de décision).
# 6. **Actionneur / Sortie** : texte généré, commande robotique, appel d’API, etc.
#
# ### 4. Exemples concrets
#
# | Domaine | Agent IA | Fonctionnement |
# |--------|----------|----------------|
# | **Assistants vocaux** | Siri, Alexa, Google Assistant | Reconnaissance vocale → compréhension du langage → recherche d’information → réponse ou commande domotique. |
# | **Jeux vidéo** | IA de *StarCraft II* (AlphaStar) | Analyse de l’état du jeu → planification stratégique → actions en temps réel. |
# | **Robots industriels** | Bras robotisé de montage | Capteurs de force → modèle de perception → contrôle en boucle fermée pour saisir des pièces. |
# | **Finance** | Algorithme de trading | Flux de données de marché → modèle prédictif → décision d’achat/vente. |
# | **Santé** | Agent de suivi de patients | Données de capteurs (pulsations, glucose) → détection d’anomalies → alerte médecin ou recommandation. |
#
# ### 5. Pourquoi parler d’« agent » ?
#
# - **Autonomie** : L’agent agit sans supervision humaine constante.
# - **Adaptabilité** : Il peut ajuster son comportement en fonction de nouvelles données.
# - **Interaction** : Il échange avec des humains ou d’autres systèmes (multi‑agents).
# - **Objectif‑orienté** : Il poursuit un but défini (maximiser un gain, minimiser un risque, etc.).
#
# ### 6. Défis et limites
#
# | Problème | Description |
# |----------|-------------|
# | **Compréhension du contexte** | Les agents peuvent perdre le fil d’une conversation longue ou d’un environnement dynamique. |
# | **Robustesse** | Sensibles aux entrées bruitées ou adversariales (ex. : attaques de type « adversarial examples »). |
# | **Éthique & Biais** | Les modèles d’apprentissage peuvent reproduire ou amplifier des biais présents dans les données d’entraînement. |
# | **Explicabilité** | Les décisions prises par des réseaux de neurones profonds sont souvent opaques (« boîte noire »). |
# | **Sécurité** | Un agent mal conçu peut exécuter des actions dangereuses (ex. : robots industriels hors‑contrôle). |
#
# ### 7. Ressources pour aller plus loin
#
# - **Livres** :
#   - *Artificial Intelligence: A Modern Approach* (Russell & Norvig) – chapitres sur les agents.
#   - *Reinforcement Learning: An Introduction* (Sutton & Barto).
#
# - **Cours en ligne** :
#   - Coursera – *AI for Everyone* (Andrew Ng).
#   - edX – *Multi‑Agent Systems* (Université de Queensland).
#
# - **Bibliothèques & Frameworks** :
#   - **OpenAI Gym** / **PettingZoo** (environnements de simulation d’agents).
#   - **ROS** (Robot Operating System) pour les agents robotiques.
#   - **Rasa**, **Dialogflow** pour les agents conversationnels.
#
# ---
#
# ### 🎯 En résumé
#
# Un **agent IA** est un système capable de **percevoir**, **raisonner** et **agir** de façon autonome dans un environnement donné, en poursuivant un objectif. Il combine des techniques de **perception** (vision, parole, texte), de **modélisation** (représentations internes) et de **prise de décision** (règles, planification, apprentissage). Les agents IA sont aujourd’hui omniprésents : assistants vocaux, robots, jeux vidéo, systèmes de recommandation, etc., mais ils soulèvent également des questions importantes de sécurité, d’éthique et d’explicabilité.
# None

# %%
from langchain.tools import tool

@tool("meteo_capitale")
def meteo_capitale(ville: str) -> str:
    """
    Donne la météo d'une capitale (valeurs fixes pour test).

    Args:
        ville: nom de la capitale
    """

    print("tool meteo_capitale utilisé")

    temperature = 25
    humidite = 60
    pression = 1013

    return (
        f"Météo à {ville} : "
        f"Température = {temperature}°C, "
        f"Humidité = {humidite}%, "
        f"Pression = {pression} hPa"
    )

# %%
from langchain.agents import create_agent
from langchain.messages import SystemMessage, HumanMessage
from langchain_ollama import ChatOllama

model = ChatOllama(model="llama3.2")

system_prompt = "Utilises les tools pour répondre aux questions"
agent = create_agent(
                    model=model,
                    tools=[meteo_capitale],
                    system_prompt=system_prompt,
                    )

# %%
question = HumanMessage(content="Quelle est la météo à Capitole lunaire ?")
response = agent.invoke(
{"messages": [question]}
)
print(response['messages'][-1].content)
# Out:
# tool meteo_capitale utilisé
# Résultat de la recherche sur la météo à Capitole lunaire :
#
# La météo actuelle à Capitole lunaire est la suivante :
# - Température : 25°C
# - Humidité : 60%
# - Pression atmosphérique : 1013 hPa
#
# Il est recommandé de prendre un chapeau et des lunettes de soleil pour éviter les dégâts causés par le soleil élevé.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from tavily import TavilyClient
from typing import Any , Dict 

tavily_client = TavilyClient()

@tool("web_search")

def web_search(query: str) -> Dict[str, Any]:
     """Effectue une recherche web en utilisant l'API de Tavily. Args: query: la requête de recherche """
     return tavily_client.search(query)
web_search.invoke("Qui est le Président de commune actuel de Marrakech ?")
# Out:
# {'query': 'Qui est le Président de commune actuel de Marrakech ?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://archive.challenge.ma/la-presidence-des-communes-et-des-provinces-se-precisent-dheure-en-heure-55594/',
#    'title': 'La présidence des communes et des provinces se précise | Challenge.ma',
#    'content': 'La présidence des communes et des provinces se précise | Challenge.ma. Comme attendu, le PJDiste Mohamed Larbi Belkaid est désormais le nouveau maire de la ville de Marrakech. Pour Casablanca, le nouveau maire de la ville est Abdelaziz Omari du PJD. Il a été porté à la présidence du conseil communal de la ville blanche par une écrasante majorité de\xa0124 voix sur les 147. A Agadir, c’est Salah El Malouki qui a été consacré nouveau Maire de la ville avec\xa044 voix sur 65, sachant qu’il y a eu 18 abstentions et 3 absences. L’autre candidat à la présidence du conseil de la ville n’était autre que Rachid Talbi Alami, le Président de la chambre des représentants qui s’est retiré finalement à la dernière minute. C’est Jamal Ben Rabiaa qui a été élu président du conseil de la ville avec 30 voix sur 43. Des voix se sont mêmes élevées pour barrer la route à Omar Hjira l’actuel président du conseil de la ville de l’oriental.',
#    'score': 0.8815438,
#    'raw_content': None},
#   {'url': 'https://www.ville-marrakech.ma/bureau-du-conseil-communal-de-marrakech/',
#    'title': 'Ville Marrakech',
#    'content': 'Bilan des réalisations à mi-mandat (2022-2023-2024). Deuxième évaluation annuelle du plan d’action de la commune de Marrakech 2025. ## Bureau du Conseil Communal de Marrakech. * Bureau du Conseil Communal de Marrakech. Mme Fatim Ezzahra EL MANSOURI. ### Mme Fatim Ezzahra EL MANSOURI. #### Président de la Commune de Marrakech. ### M. #### 1er Vice président du Conseil Communal de Marrakech. ### M. #### 2ème Vice président du Conseil Communal de Marrakech. ### M. #### 3ème Vice président du Conseil Communal de Marrakech. ### M. #### 4ème Vice président du Conseil Communal de Marrakech. ### Mme Khadija BOUHRACHI. #### 5ème Vice présidente du Conseil Communal de Marrakech. ### Mme. Atika BOUSETTA. #### 6ème Vice présidente du Conseil Communal de Marrakech. #### 7ème Vice président du Conseil Communal de Marrakech. #### 8ème Vice président du Conseil Communal de Marrakech. ### Mme. Zoubida ELMCHAMER. #### 9ème Vice présidente du Conseil Communal de Marrakech. #### 10ème Vice président du Conseil Communal de Marrakech.',
#    'score': 0.81630427,
#    'raw_content': None},
#   {'url': 'https://h24info.ma/maroc/fatima-zahra-mansouri-elue-maire-de-marrakech/',
#    'title': 'Fatima-Zahra Mansouri élue maire de Marrakech , H24info',
#    'content': "# Fatima-Zahra Mansouri élue maire de Marrakech. **La présidente du Conseil national du PAM, Fatima Zahra Mansouri, a été élue ce matin à la tête du conseil communal de Marrakech.**. Elle succède ainsi à l’ancien maire PJD de la ville Akram Belkaid. Réuni aujourd’hui à l’hôtel de ville, le Conseil communal a également élu les dix vice-présidents de la commune. Rappelons que le PAM a obtenu 48 sièges sur un total de 193 au niveau des cinq arrondissements de la ville de Marrakech : Guelliz, Sidi Youssef Ben Ali, Ennakhil, Marrakech-Médina et Ménara, outre la municipalité du Méchouar- Kasbah lors des élections générales du 08 septembre. * PAM: Fatima-Zahra Mansouri tire à boulets rouges sur Benchamach. * Décès de l’ancien maire de Marrakech, Omar Jazouli. L'ancien maire de Marrakech, Omar Jazouli, est décédé, dans la nuit de samedi à dimanche,…. L’attaquant des Lions de l’Atlas Hakim Ziyech et la championne taekwondoïste Fatima-Zahra Abou Fares ont….",
#    'score': 0.73914057,
#    'raw_content': None},
#   {'url': 'https://lematin.ma/express/2021/fatima-zahra-mansouri-elue-presidente-conseil-marrakech/364526.html',
#    'title': 'Fatima-Zahra Mansouri élue présidente du Conseil communal de Marrakech - Le Matin.ma',
#    'content': 'Suivez-nous sur notre chaîne WhatsApp. La présidente du Conseil national du PAM, qui a déjà affiché son optimisme par rapport aux résultats du vote pour diriger le Conseil de la ville de Marrakech, devient maire de la ville ocre. Mme Mansouri s’est présentée à la présidence du Conseil de la ville de Marrakech, après que notre parti ait obtenu la première place, soit 48 sièges dans les cinq arrondissements de la ville, à savoir Gueliz, Menara, Nakhil, Médina et Sidi Youssef Ben Ali, sur un total de 179 constituant le conseil communal. Nous utilisons des cookies pour vous apporter la meilleure expérience possible sur notre site Web. Vos préférences des cookies seront enregistrées dans la mémoire locale de votre navigateur. En outre, vous pouvez décider librement d’accepter ou de refuser les cookies, et modifier ces critères à tout moment, pour améliorer la performance du site Web, ainsi que les cookies permettant d’afficher du contenu personnalisé en fonction de vos intérêts.',
#    'score': 0.7293082,
#    'raw_content': None},
#   {'url': 'https://fr.le360.ma/politique/presidents-de-communes-la-liste-des-limogeages-sallonge_XOWP57I3MBF5TNHHENNGCLG3VM/',
#    'title': 'Présidents de commune: la liste des limogeages s’allonge | le360.ma',
#    'content': '## Revue de presseL’assainissement du fichier des collectivités territoriales se poursuit par la révocation des présidents, des vice-présidents et des élus véreux, à l’échelle nationale. «*La justice administrative de Marrakech, qui a agi suite à une requête du gouverneur de la province de Youssoufia, a également révoqué de leurs fonctions le premier vice-président de cette commune et la sixième vice-présidente du Conseil*», relaie le quotidien. La requête déposée par le gouverneur de la province de Youssoufia auprès de la justice administrative compétente de Marrakech se fondait sur le rapport de l’inspection générale de l’administration territoriale (IGAT), qui avait relevé des dysfonctionnements dans la gestion des affaires locales de la commune. Ce même jour, ajoute *Al Ahdath Al Maghribia*, dans cette même wilaya de la région de Marrakech-Safi, la justice administrative a révoqué de ses fonctions le président de la commune urbaine de Safi, Nourddine Kemmouch, élu du Parti de l’Istiqlal (PI).',
#    'score': 0.725824,
#    'raw_content': None}],
#  'response_time': 1.81,
#  'request_id': 'e09b7950-3706-4817-a516-5d3cd4148865'}

# %%
agent = create_agent(
model=model,
tools=[web_search]
)
question = HumanMessage(content="Qui est le Président de commune actuel de Marrakech ?")
response = agent.invoke(
{"messages": [question]})
print(response['messages'][-1].content)
# Out:
# Le Président de la Commune d'Marrakech est Fatima-Zahra Mansouri.
